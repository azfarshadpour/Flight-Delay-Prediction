# %% [markdown]
# ## Exploratory Data Analysis
#
# Use this notebook to get familiar with the datasets we have. There is 10 questions we need to answer during the EDA.
#
#
# We shouldn't limit our EDA to these 10 questions. Let's be creative :).

# %%
import pandas as pd 
import numpy as np 
from PIL import Image

# %%
flights = pd.read_csv(r'/Users/ateam/lighthouse-data-notes/Week_5/Day_5/Data/df_50000_flights.csv')

# %%
flights.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0     8734622  2018-07-23                 UA                 UA          UA
# 1     5977241  2018-05-13                 WN                 WN          WN
# 2    11733397  2018-01-02                 WN                 WN          WN
# 3    14361951  2019-06-02                 AA                 AA          AA
# 4     9691946  2019-04-04                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                 554                UA   N68842                554
# 1                2188                WN   N718SW               2188
# 2                5011                WN   N7845A               5011
# 3                1687                AA   N723UW               1687
# 4                5297                OH   N524AE               5297
#
#    origin_airport_id  ... dest_airport_id dest    dest_city_name crs_dep_time  \
# ...

# %% [markdown]
# #### **Task 1**: Test the hypothesis that the delay is from Normal distribution. and that **mean** of the delay is 0. Be careful about the outliers.

# %%
# The below distribution shows the distribution of the delay time with and without outliers. The standard deviation of the delay time is 51.83

DelayDistribution = Image.open("Delay Time Distribution with Outliers.png")
DelayDistribution
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=852x504 at 0x11CBDE280>

# %%
DelayDistNoOutliers = Image.open("Delay Time Distribution Without Outliers.png")
DelayDistNoOutliers
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1232x754 at 0x11CBDEA90>

# %%
DelayDist = Image.open("Delay Time.png")
DelayDist
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2236x1314 at 0x11CC6F280>

# %% [markdown]
# #### **Task 2**: Is average/median monthly delay different during the year? If yes, which are months with the biggest delays and what could be the reason?

# %%
# The below distribution displayed the average delay by month

AverageMonthlyDelay = Image.open("Average Delay by Month.png")
AverageMonthlyDelay
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2474x1452 at 0x11BA88190>

# %% [markdown]
# #### **Task 3**: Does the weather affect the delay?
# Use the API to pull the weather information for flights. There is no need to get weather for ALL flights. We can choose the right representative sample. Let's focus on four weather types:
# - sunny
# - cloudy
# - rainy
# - snow.
# Test the hypothesis that these 4 delays are from the same distribution. If they are not, which ones are significantly different?

# %%
# The image below displays a distribution of the weather related delays by month

WeatherDelayByMonth = Image.open("Weather Delay by Month.png")
WeatherDelayByMonth
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2318x1378 at 0x11BA5E790>

# %% [markdown]
# #### **Task 4**: How taxi times changing during the day? Does higher traffic lead to bigger taxi times?

# %%
# The image below displays a distribution of the average taxi in/out time by day (above) and the traffic volume (below)

TaxiTimeFlightVol = Image.open("Taxi Time by Hour vs Flight Volume.png")
TaxiTimeFlightVol
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1582x1360 at 0x11BA882E0>

# %% [markdown]
# #### **Task 5**: What is the average percentage of delays that is already created before departure? (aka are arrival delays caused by departure delays?) Are airlines able to lower the delay during the flights?

# %%
# The below distribution illustrates that the majority of flights that arrive delayed had departure delays.

LateArrivalDepartureStatus = Image.open("Late Departures Arrival Status.png")
LateArrivalDepartureStatus
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2038x1492 at 0x11BA884F0>

# %%
# The below distribution illustrates the total amount of delay vs arrival time for flights that leave late

DeparturevsArrivalDelay = Image.open("Departure vs Arrival Delay.png")
DeparturevsArrivalDelay
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2006x294 at 0x11CBCF970>

# %% [markdown]
# #### **Task 6**: How many states cover 50% of US air traffic?

# %%
# Based on the origin location of flights, 7 states make up 50% of all flight traffic

FlightVolumeByState = Image.open("States 50% Flight Traffic.png")
FlightVolumeByState
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2000x530 at 0x11CBDE0D0>

# %% [markdown]
# #### **Task 7**: Test the hypothesis whether planes fly faster when there is the departure delay?

# %%
# The below charts illustrate the actual vs scheduled airtime of flights that leave late. The difference between these two bars is more pronounced than of those in the chart below indicating that flights with late departures do fly faster
 
LateDepartureVAirtime = Image.open("Late Departure Scheduled vs Elapsed Airtime.png")
LateDepartureVAirtime
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1674x304 at 0x11CBCF670>

# %%
# Below illustrates the actual vs scheduled airtime of flights that depart early or on time

EarlyOntimeDepartureVAirtime = Image.open("EarlyOnTime Departures vs Elapsed Airtime.png")
EarlyOntimeDepartureVAirtime
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1678x326 at 0x11CC6F580>

# %% [markdown]
# #### **Task 8**: When (which hour) do most 'LONG', 'SHORT', 'MEDIUM' haul flights take off?

# %%
FlightLengthByDept = Image.open("Short, Medium + Long Haul by Departure.png")
FlightLengthByDept
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2186x1450 at 0x11CBDE7C0>

# %% [markdown]
# #### **Task 9**: Find the top 10 the bussiest airports. Does the biggest number of flights mean that the biggest number of passengers went through the particular airport? How much traffic do these 10 airports cover?

# %%
# Below is a list of the top 10 busiest airports based on flight origin location by volume
# In the period of analysis 2,622,300 flights originated from top 10 airports vs 8,091,628 flights originating from all airports in total. The traffic at the top 10 airports accounts fo 32% of all flight traffic

BusiestAirports = Image.open("Top 10 Busiest Airports.png")
BusiestAirports
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1826x646 at 0x11BA88A90>

# %% [markdown]
# #### **Task 10**: Do bigger delays lead to bigger fuel comsumption per passenger?
# We need to do four things to answer this as accurate as possible:
# - Find out average monthly delay per air carrier (monthly delay is sum of all delays in 1 month)
# - Find out distance covered monthly by different air carriers
# - Find out number of passengers that were carried by different air carriers
# - Find out total fuel comsumption per air carrier.
#
# Use this information to get the average fuel comsumption per passenger per km. Is this higher for the airlines with bigger average delays?

# %%
# Below is a list of monthly delay by carrier 
MonthlyDelayByCarrier = Image.open("Avg Monthly Delay by Carrier.png")
MonthlyDelayByCarrier
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1668x1356 at 0x11CBCF7C0>

# %%
# Below is a list of total passengers by carrier in decending order. Only the top carriers are listed. 
PassengersByCarrier = Image.open("Passengers by Carrier.png")
PassengersByCarrier
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=506x1452 at 0x11CBDE700>

# %%
# Below is a list the distances travelled monthly by carrier
MonthlyDistancebyCarrier = Image.open("Monthly Distance by Carrier.png")
MonthlyDistancebyCarrier
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2116x1346 at 0x11CBDED90>

# %%
# Below is decending distribution of total gallons of fuel consumped by carrier. 
FuelByCarrier = Image.open("Fuel Consumption by Carrier.png")
FuelByCarrier
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1918x1326 at 0x11CBDE4C0>
